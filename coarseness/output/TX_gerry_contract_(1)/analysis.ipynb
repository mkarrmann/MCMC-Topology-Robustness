# %%
import json

with open("results.json") as f:
    results = json.load(f)

# %%
for i in range(8):
    print(results[i*18:(i+1)*18])
# Out:
# [22.096316666666667, 21.9533, 21.921533333333333, 21.995366666666666, 21.982733333333332, 22.034, 21.941783333333333, 21.943683333333333, 22.063233333333333, 21.6618, 22.056916666666666, 21.782083333333333, 21.3792, 21.411333333333335, 21.06415, 22.076583333333332, 21.30715, 19.42295]
# [21.93185, 21.999366666666667, 22.120666666666665, 21.937383333333333, 22.0433, 22.05305, 22.0534, 22.105766666666668, 22.017666666666667, 21.94465, 22.077666666666666, 22.02825, 21.982866666666666, 21.9639, 21.169416666666667, 20.897666666666666, 19.49035, 17.64816666666667]
# [22.249083333333335, 22.060416666666665, 22.2118, 22.200966666666666, 22.090416666666666, 22.02316666666667, 22.124016666666666, 22.159566666666667, 22.1996, 21.9364, 22.07945, 22.001666666666665, 21.920166666666667, 22.0522, 21.73985, 21.938266666666667, 19.08353333333333, 17.49415]
# ...
